# %%
import random
import re
import sys
from os import system

fonte_pilotos = open("../../jupyter/Desafio_2/Pilotos_2022.txt",'r')
fonte_circuitos = open("../../jupyter/Desafio_2/Circuito_2022.txt",'r')
fonte_pontos = open("../../jupyter/Desafio_2/Pontos_2022.txt",'r')

pilotos = {}
circuitos = {}
pontos = {}
lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
flag = 0

for x in fonte_pilotos:
#    piloto = x.strip().split(',')
    numero, nome, pais, equipa, mota = x.strip().split(',')
    pilotos[nome] = [numero, pais, equipa, mota, []]
fonte_pilotos.close()

for c in fonte_circuitos:
    nome, país, distancia = c.strip().split(',')
    circuitos[nome] = [país, distancia, []]
fonte_circuitos.close()

for p in fonte_pontos:
    ponto = p.strip().split(',')
    pontos[ponto[0]] = ponto[1]
fonte_pontos.close()

def Pilotos():
    lista_menu = ['Listar pilotos', 'Classificação geral', 'Classificação por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)    
    input("Press Enter to Continue\n")
    system('cls')

def ListarPilotos():
    print('\n', 'Nome'.ljust(22),'Número'.ljust(7), 'País'.ljust(6), 'Equipa'.ljust(30), 'Mota','\n')    
    for x in pilotos:
        print(x.ljust(25), pilotos[x][0].ljust(5), pilotos[x][1].ljust(5), pilotos[x][2].ljust(30), pilotos[x][3])
    print('\n', '\n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def ClassificaçãoGeral():
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificação Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        else:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls') 

def MenuClassificaçãoPorGP():
    lista_menu = ['Escolher circuito', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def EscolherCircuitoPilotos():
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 1)
    input("Press Enter to Continue\n")
    system('cls')

def ClassificaçãoPorGP(circuito):
    
    print('\n' + circuito + '!!!\n\nOrdem      Nome           Pontos\n')
    i=1
    if circuitos[circuito][2] != []:
        for x in circuitos[circuito][2]:        
            if i < 10:
                print('', i, '  ', x[2].ljust(25), x[1])
            else:
                print(i, '  ',  x[2].ljust(25), x[1])            
            i+=1
    else:
        print('Tem que escolher um GP realizado !!!')
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def GrandePremio():
    lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def RealizarGP():
    
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 2)
    input("Press Enter to Continue\n")
    system('cls')
    
def Realizar_GP(circuito):
    
    replica_pilotos = list(pilotos)
    i=1
    while replica_pilotos:
        try:
            pont = int(pontos[str(i)])
        except:
            pont = 0
        piloto = random.choice(replica_pilotos)
        replica_pilotos.remove(piloto)
        pilotos[piloto][4].append((circuito, pont))
        circuitos[circuito][2].append((pilotos[piloto][2],pont, piloto))

        i+=1
  
    print('\n GP realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def VencedoresPorGP():
    
    for x in circuitos:
        print(x, circuitos[x][0], circuitos[x][2][0][2])
    
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def Campeonato():
    lista_menu = ['Realizar campeonato', 'Os dez primeiros do campeonato', 'Os primeiros de cada GP','As três melhores equipas', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def RealizarCampeonato():
    for gp in circuitos:
        replica_pilotos = list(pilotos)
        i=1
        while replica_pilotos:
            try:
                pont = int(pontos[str(i)])
            except:
                pont = 0
            piloto = random.choice(replica_pilotos)
            replica_pilotos.remove(piloto)
            pilotos[piloto][4].append((gp, pont))
            circuitos[gp][2].append((pilotos[piloto][2],pont, piloto))

            i+=1
  
    print('\n Campeonato realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')


    
    
    
    
    
    
    
    
    

    
    
    
    
def DezPrimeiros():
   
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificação Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        elif i < 11:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls') 

def TresEquipas():
    equipas = {}
    pilotos = {}

    for x in circuitos:
        circuito = circuitos[x]
        classificacao = circuito[2]
        for c in classificacao:
            equipa, pontos, piloto = c
            if equipa in equipas:
                equipas[equipa] = equipas[equipa] + pontos
            else:
                equipas[equipa] = pontos
            if piloto in pilotos:
                pilotos[piloto] = pilotos[piloto] + pontos
            else:
                pilotos[piloto] = pontos            
    tresequipas = sorted(equipas.items(), reverse=True, key=lambda item: item[1])
#    for x in range(3):
#        print(tresequipas[x][0], tresequipas[x][1])
    #    print(sorted(pilotos.items(), reverse=True, key=lambda item: item[1]))
#    print(sorted(equipas.items(), reverse=True, key=lambda item: item[1]))
    primeiros(tresequipas, 3)

def primeiros(equipas, limite):
    i = 0
    for e in equipas:
        if i < limite:
            print('{} {}'.format(e[0], e[1]))
        i = i+1

    
def Exit():  
    system('cls')
    print("Goodbye")
    sys.exit()   
def MenuAnterior():
    lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def display_menu(menu_items):
    for x in menu_items:
        print('\n', x, menu_items.get(x), '\n')

def Menu(lista_menu, flag):
    menu_items = dict(enumerate(lista_menu, start=1))
    while True:
        display_menu(menu_items)        
        try:
            selection = int(input("Escolha um valor do menu: \n"))
        except:
            print('Introduza um algarismo !')
        else:
            try:
                selected = menu_items[selection]
                break
            except:
                print('Escolha um valor do menu !')
            else:
                break
    nome_menu = {'Pilotos' : Pilotos,
                 'Grande Premio' : GrandePremio,
                 'Campeonato' : Campeonato,
                 'Exit' : Exit,
                 'Os dez primeiros do campeonato' : DezPrimeiros,
                 'As três melhores equipas' : TresEquipas,
                 'Menu anterior' : MenuAnterior,
                 'Os primeiros de cada GP' : VencedoresPorGP,
                 'Realizar GP' : RealizarGP,
                 'Classificação geral' : ClassificaçãoGeral,
                 'Realizar campeonato' : RealizarCampeonato,
                 'Escolher circuito' : EscolherCircuitoPilotos,
                 'Listar pilotos' : ListarPilotos,
                 'Classificação por GP' : MenuClassificaçãoPorGP,
                 'Os vencedores por GP' : VencedoresPorGP
    }
    if flag == 0:
        executa_funcao = nome_menu[selected]
        executa_funcao()
    elif flag == 1:
        ClassificaçãoPorGP(selected)
    elif flag == 2:
        Realizar_GP(selected)
    
Menu(lista_menu,0)
# Out:
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  1
#  Campeonato realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  4
# Repsol Honda Team 284
# Team SUZUKI ECSTAR 274
# Red Bull KTM Factory Racing 271
# Press Enter to Continue
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in <module>
#     304         Realizar_GP(selected)
#     305
# --> 306 Menu(lista_menu,0)
#
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in Menu(lista_menu, flag)
#     298     if flag == 0:
#     299         executa_funcao = nome_menu[selected]
# --> 300         executa_funcao()
#     301     elif flag == 1:
#     302         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in Campeonato()
#     151 def Campeonato():
#     152     lista_menu = ['Realizar campeonato', 'Os dez primeiros do campeonato', 'Os primeiros de cada GP','As três melhores equipas', 'Menu anterior', 'Exit']
# --> 153     Menu(lista_menu, 0)
#     154     input("Press Enter to Continue\n")
#     155     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in Menu(lista_menu, flag)
#     298     if flag == 0:
#     299         executa_funcao = nome_menu[selected]
# --> 300         executa_funcao()
#     301     elif flag == 1:
#     302         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in RealizarCampeonato()
#     174
#     175     lista_menu = ['Menu anterior', 'Exit']
# --> 176     Menu(lista_menu, 0)
#     177     input("Press Enter to Continue\n")
#     178     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in Menu(lista_menu, flag)
#     298     if flag == 0:
#     299         executa_funcao = nome_menu[selected]
# --> 300         executa_funcao()
#     301     elif flag == 1:
#     302         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_14660\2294418490.py in MenuAnterior()
#     257     lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
#     258     Menu(lista_menu, 0)
# --> 259     input("Press Enter to Continue\n")
#     260     system('cls')
#     261
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
