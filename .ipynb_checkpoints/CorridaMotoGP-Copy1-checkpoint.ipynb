# %%
import random

fonte_pilotos = open("../../jupyter/Desafio_2/Pilotos_2022_.txt",'r')
fonte_circuitos = open("../../jupyter/Desafio_2/Circuito_2022_.txt",'r')
fonte_pontos = open("../../jupyter/Desafio_2/Pontos_2022.txt",'r')

pilotos = {}
circuitos = {}
pontos = {}

for x in fonte_pilotos:
    piloto = x.strip().split(',')
    pilotos[piloto[1]] = [piloto[0], piloto[2], piloto[3], piloto[4]]
fonte_pilotos.close()

for c in fonte_circuitos:
    circuito = c.strip().split(',')
    circuitos[circuito[0]] = [circuito[1], circuito[2]]
fonte_circuitos.close()

for p in fonte_pontos:
    ponto = p.strip().split(',')
    pontos[ponto[0]] = ponto[1]
fonte_pontos.close()

resultados = {}
classificacao = []
#piloto_acumulado=[]
piloto_acumulado={}

for gp in circuitos:
    replica_pilotos = list(pilotos)
    classificacao = []
    i=1
#    j=0
    while replica_pilotos:
#        piloto_temp = []
        temp = int(pontos[str(i)])
        piloto = random.choice(replica_pilotos)
        replica_pilotos.remove(piloto)
        piloto_temp = [piloto, temp]
#        piloto_acumulado.append([piloto, temp])
        piloto_acumulado[piloto] = temp
        classificacao.append(piloto_temp)
#        classificacao.append(temp)
        i+=1
#    j+=1
    resultados[gp] = classificacao
'''    
i=0
#j=0
for x in resultados.values():
    print(x)
    print(x[i][0])
    i+=1
'''  
'''
    temp = sum(int(x[0][i]))
    i+=1
    j+=1
'''        
        
#    int(resultados.get(resultados)[0][1]))
#print(piloto_acumulado) 
'''
for x in pilotos:
    newlist = []
    temp = 0
    for y in piloto_acumulado:
        if piloto_acumulado.keys() == str(pilotos.keys()):
            temp += int(piloto_acumulado.values())
        newlist.append([str(pilotos.keys()), temp])
    print(newlist)'''
#print(resultados)
#print('\n' + resultados.get('Phillip Island')[0][0])
#print('\n' + str(resultados.get('Phillip Island')[0][1]))
#temp = sum(int(resultados[0][i]
#for x in resultados:
#        print('\n' + resultados.get('Phillip Island')[0][1])
print(piloto_acumulado)
#print(circuitos)
#print(pilotos.keys())
#print(pontos)
# Out:
# [["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0], ["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0], ["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0]]
# [["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0], ["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0], ["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0]]
# [["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0], ["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0], ["dict_keys(['Francesco Bagnaia', 'Fabio Quartararo', 'Enea Bastianini'])", 0]]
# {'Fabio Quartararo': 25, 'Enea Bastianini': 16, 'Francesco Bagnaia': 20}
