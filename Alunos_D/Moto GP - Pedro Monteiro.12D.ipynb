# %%
import random
import re
import sys
from os import system

fonte_pilotos = open("Pilotos_2022.txt",'r')
fonte_circuitos = open("Circuito_2022.txt",'r')
fonte_pontos = open("Pontos_2022.txt",'r')

pilotos = {}
circuitos = {}
pontos = {}
lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
flag = 0

for x in fonte_pilotos:
#    piloto = x.strip().split(',')
    numero, nome, pais, equipa, mota = x.strip().split(',')
    pilotos[nome] = [numero, pais, equipa, mota, []]
fonte_pilotos.close()

for c in fonte_circuitos:
    nome, país, distancia = c.strip().split(',')
    circuitos[nome] = [país, distancia, []]
fonte_circuitos.close()

for p in fonte_pontos:
    ponto = p.strip().split(',')
    pontos[ponto[0]] = ponto[1]
fonte_pontos.close()

def Pilotos():
    lista_menu = ['Listar pilotos', 'Classificação geral', 'Classificação por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)    
    system('cls')

def ListarPilotos():
    print('\n', 'Nome'.ljust(22),'Número'.ljust(7), 'País'.ljust(6), 'Equipa'.ljust(30), 'Mota','\n')    
    for x in pilotos:
        print(x.ljust(25), pilotos[x][0].ljust(5), pilotos[x][1].ljust(5), pilotos[x][2].ljust(30), pilotos[x][3])
    print('\n', '\n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')
    
def ClassificaçãoGeral():
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificação Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        else:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls') 

def MenuClassificaçãoPorGP():
    lista_menu = ['Escolher circuito', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')

def EscolherCircuitoPilotos():
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 1)
    system('cls')

def ClassificaçãoPorGP(circuito):
    
    print('\n' + circuito + '!!!\n\nOrdem      Nome           Pontos\n')
    i=1
    if circuitos[circuito][2] != []:
        for x in circuitos[circuito][2]:        
            if i < 10:
                print('', i, '  ', x[2].ljust(25), x[1])
            else:
                print(i, '  ',  x[2].ljust(25), x[1])            
            i+=1
    else:
        print('Tem que escolher um GP realizado !!!')
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    system('cls')
    
def GrandePremio():
    lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')

def RealizarGP():
    
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 2)
    system('cls')

    
def Realizar_GP(circuito):
    
    replica_pilotos = list(pilotos)
    i=1
    while replica_pilotos:
        try:
            pont = int(pontos[str(i)])
        except:
            pont = 0
        piloto = random.choice(replica_pilotos)
        replica_pilotos.remove(piloto)
        pilotos[piloto][4].append((circuito, pont))
        circuitos[circuito][2].append((pilotos[piloto][2],pont, piloto))

        i+=1
  
    print('\n GP realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')

def VencedoresPorGP():
    try:
        print(" ".ljust(7), "Circuitos".ljust(38), "País".ljust(36), "Pilotos")
        for x in circuitos:
            print(x.ljust(45), circuitos[x][0].ljust(35), circuitos[x][2][0][2])
    except IndexError:
        print("Há GPs por realizar")
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')
    
def Campeonato():
    lista_menu = ['Realizar campeonato', 'Os dez primeiros do campeonato', 'Os primeiros de cada GP','As três melhores equipas', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')

def RealizarCampeonato():
    for gp in circuitos:
        replica_pilotos = list(pilotos)
        i=1
        while replica_pilotos:
            try:
                pont = int(pontos[str(i)])
            except:
                pont = 0
            piloto = random.choice(replica_pilotos)
            replica_pilotos.remove(piloto)
            pilotos[piloto][4].append((gp, pont))
            circuitos[gp][2].append((pilotos[piloto][2],pont, piloto))

            i+=1
  
    print('\n Campeonato realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')

def DezPrimeiros():
   
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificação Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        elif i<11:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls') 

def TresEquipas():
    
    equipas = {}
    pilotos = {}

    for x in circuitos:
        circuito = circuitos[x]
        classificacao = circuito[2]
        for c in classificacao:
            equipa, pontos, piloto = c
            if equipa in equipas:
                equipas[equipa] = equipas[equipa] + pontos
            else:
                equipas[equipa] = pontos
            if piloto in pilotos:
                pilotos[piloto] = pilotos[piloto] + pontos
            else:
                pilotos[piloto] = pontos            
    tres = sorted(equipas.items(), reverse=True, key=lambda item: item[1])
    primeiros(tres, 3)
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    system('cls')
    
def primeiros(equipas, limite):
    i = 0
    for e in equipas:
        if i < limite:
            print('{} {}'.format(e[0], e[1]))
        i = i+1

def Exit():  
    system('cls')
    print("Simulação Encerrada")
    SystemExit
    
def MenuAnterior():
    lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
    Menu(lista_menu, 0)
    system('cls')
    
def display_menu(menu_items):
    for x in menu_items:
        print('\n', x, menu_items.get(x), '\n')

def Menu(lista_menu, flag):
    menu_items = dict(enumerate(lista_menu, start=1))
    while True:
        display_menu(menu_items)        
        try:
            selection = int(input("Escolha um valor do menu: \n"))
        except:
            print('Introduza um algarismo !')
        else:
            try:
                selected = menu_items[selection]
                break
            except:
                print('Escolha um valor do menu !')
            else:
                break
    nome_menu = {'Pilotos' : Pilotos,
                 'Grande Premio' : GrandePremio,
                 'Campeonato' : Campeonato,
                 'Exit' : Exit,
                 'Os dez primeiros do campeonato' : DezPrimeiros,
                 'As três melhores equipas' : TresEquipas,
                 'Menu anterior' : MenuAnterior,
                 'Os primeiros de cada GP' : VencedoresPorGP,
                 'Realizar GP' : RealizarGP,
                 'Classificação geral' : ClassificaçãoGeral,
                 'Realizar campeonato' : RealizarCampeonato,
                 'Escolher circuito' : EscolherCircuitoPilotos,
                 'Listar pilotos' : ListarPilotos,
                 'Classificação por GP' : MenuClassificaçãoPorGP,
                 'Os vencedores por GP' : VencedoresPorGP
    }
    if flag == 0:
        executa_funcao = nome_menu[selected]
        executa_funcao()
    elif flag == 1:
        ClassificaçãoPorGP(selected)
    elif flag == 2:
        Realizar_GP(selected)
    
Menu(lista_menu,0)
# Out:
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Listar pilotos
#
#
#  2 Classificação geral
#
#
#  3 Classificação por GP
#
#
#  4 Menu anterior
#
#
#  5 Exit
# Escolha um valor do menu:
#  3
#  1 Escolher circuito
#
#
#  2 Menu anterior
#
#
#  3 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
# Circuit Ricardo Tormo!!!
#
# Ordem      Nome           Pontos
#
# Tem que escolher um GP realizado !!!
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Listar pilotos
#
#
#  2 Classificação geral
#
#
#  3 Classificação por GP
#
#
#  4 Menu anterior
#
#
#  5 Exit
# Escolha um valor do menu:
#  2
#    Classificação Geral !!!
#
# Ordem      Nome           Pontos
#
#  1    Francesco Bagnaia         0
#  2    Fabio Quartararo          0
#  3    Enea Bastianini           0
#  4    Aleix Espargaro           0
#  5    Jack Miller               0
#  6    Brad Binder               0
#  7    Alex Rins                 0
#  8    Johann Zarco              0
#  9    Jorge Martin              0
# 10    Miguel Oliveira           0
# 11    Maverick ViÃ±ales         0
# 12    Luca Marini               0
# 13    Marc Marquez              0
# 14    Marco Bezzecchi           0
# 15    Joan Mir                  0
# 16    Pol Espargaro             0
# 17    Alex Marquez              0
# 18    Takaaki Nakagami          0
# 19    Franco Morbidelli         0
# 20    Fabio Di Giannantonio     0
# 21    Andrea Dovizioso          0
# 22    Raul Fernandez            0
# 23    Remy Gardner              0
# 24    Darryn Binder             0
# 25    Cal Crutchlow             0
# 26    Stefan Bradl              0
# 27    Michele Pirro             0
# 28    Lorenzo Savadori          0
# 29    Tetsuta Nagashima         0
# 30    Danilo Petrucci           0
# 31    Kazuki Watanabe           0
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Listar pilotos
#
#
#  2 Classificação geral
#
#
#  3 Classificação por GP
#
#
#  4 Menu anterior
#
#
#  5 Exit
# Escolha um valor do menu:
#  1
#  Nome                   Número  País   Equipa                         Mota
#
# Francesco Bagnaia         63    IT    Ducati Lenovo Team             Ducati
# Fabio Quartararo          20    FR    Monster Energy Yamaha MotoGP   Yamaha
# Enea Bastianini           23    IT    Gresini Racing MotoGP          Ducati
# Aleix Espargaro           41    ES    Aprilia Racing                 Aprilia
# Jack Miller               43    AU    Ducati Lenovo Team             Ducati
# Brad Binder               33    ZA    Red Bull KTM Factory Racing    KTM
# Alex Rins                 42    ES    Team SUZUKI ECSTAR             Suzuki
# Johann Zarco              5     FR    Prima Pramac Racing            Ducati
# Jorge Martin              89    ES    Prima Pramac Racing            Ducati
# Miguel Oliveira           88    PT    Red Bull KTM Factory Racing    KTM
# Maverick ViÃ±ales         12    ES    Aprilia Racing                 Aprilia
# Luca Marini               10    IT    Mooney VR46 Racing Team        Ducati
# Marc Marquez              93    ES    Repsol Honda Team              Honda
# Marco Bezzecchi           72    IT    Mooney VR46 Racing Team        Ducati
# Joan Mir                  36    ES    Team SUZUKI ECSTAR             Suzuki
# Pol Espargaro             44    ES    Repsol Honda Team              Honda
# Alex Marquez              73    ES    LCR Honda CASTROL              Honda
# Takaaki Nakagami          30    JP    LCR Honda IDEMITSU             Honda
# Franco Morbidelli         21    IT    Monster Energy Yamaha MotoGP   Yamaha
# Fabio Di Giannantonio     49    IT    Gresini Racing MotoGP          Ducati
# Andrea Dovizioso          4     IT    WithU Yamaha RNF MotoGP Team   Yamaha
# Raul Fernandez            25    ES    Tech3 KTM Factory Racing       KTM
# Remy Gardner              87    AU    Tech3 KTM Factory Racing       KTM
# Darryn Binder             40    ZA    WithU Yamaha RNF MotoGP Team   Yamaha
# Cal Crutchlow             35    GB    WithU Yamaha RNF MotoGP Team   Yamaha
# Stefan Bradl              6     DE    Repsol Honda Team              Honda
# Michele Pirro             51    IT    Aruba.it Racing                Ducati
# Lorenzo Savadori          32    IT    Aprilia Racing                 Aprilia
# Tetsuta Nagashima         45    JP    LCR Honda IDEMITSU             Honda
# Danilo Petrucci           9     IT    Team SUZUKI ECSTAR             Suzuki
# Kazuki Watanabe           92    JP    Team SUZUKI ECSTAR             Suzuki
#
#
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
#  GP realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
#  GP realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Listar pilotos
#
#
#  2 Classificação geral
#
#
#  3 Classificação por GP
#
#
#  4 Menu anterior
#
#
#  5 Exit
# Escolha um valor do menu:
#  3
#  1 Escolher circuito
#
#
#  2 Menu anterior
#
#
#  3 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
# Circuit Ricardo Tormo!!!
#
# Ordem      Nome           Pontos
#
#  1    Fabio Quartararo          25
#  2    Marc Marquez              20
#  3    Pol Espargaro             16
#  4    Raul Fernandez            13
#  5    Takaaki Nakagami          11
#  6    Jack Miller               10
#  7    Lorenzo Savadori          9
#  8    Kazuki Watanabe           8
#  9    Andrea Dovizioso          7
# 10    Maverick ViÃ±ales         6
# 11    Franco Morbidelli         5
# 12    Joan Mir                  4
# 13    Johann Zarco              3
# 14    Aleix Espargaro           2
# 15    Cal Crutchlow             1
# 16    Alex Rins                 0
# 17    Remy Gardner              0
# 18    Miguel Oliveira           0
# 19    Marco Bezzecchi           0
# 20    Darryn Binder             0
# 21    Alex Marquez              0
# 22    Francesco Bagnaia         0
# 23    Fabio Di Giannantonio     0
# 24    Tetsuta Nagashima         0
# 25    Enea Bastianini           0
# 26    Michele Pirro             0
# 27    Luca Marini               0
# 28    Stefan Bradl              0
# 29    Brad Binder               0
# 30    Jorge Martin              0
# 31    Danilo Petrucci           0
# 32    Takaaki Nakagami          25
# 33    Alex Rins                 20
# 34    Maverick ViÃ±ales         16
# 35    Alex Marquez              13
# 36    Marc Marquez              11
# 37    Kazuki Watanabe           10
# 38    Johann Zarco              9
# 39    Miguel Oliveira           8
# 40    Franco Morbidelli         7
# 41    Brad Binder               6
# 42    Joan Mir                  5
# 43    Fabio Di Giannantonio     4
# 44    Pol Espargaro             3
# 45    Stefan Bradl              2
# 46    Francesco Bagnaia         1
# 47    Jack Miller               0
# 48    Jorge Martin              0
# 49    Darryn Binder             0
# 50    Michele Pirro             0
# 51    Cal Crutchlow             0
# 52    Remy Gardner              0
# 53    Lorenzo Savadori          0
# 54    Andrea Dovizioso          0
# 55    Enea Bastianini           0
# 56    Raul Fernandez            0
# 57    Danilo Petrucci           0
# 58    Tetsuta Nagashima         0
# 59    Marco Bezzecchi           0
# 60    Luca Marini               0
# 61    Fabio Quartararo          0
# 62    Aleix Espargaro           0
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  1
#  Campeonato realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  4
# Team SUZUKI ECSTAR 364
# Aprilia Racing 323
# WithU Yamaha RNF MotoGP Team 307
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  3
#         Circuitos                              País                                 Pilotos
# Circuit Ricardo Tormo                         Espanha                             Fabio Quartararo
# Sepang International Circuit                  Malasia                             Andrea Dovizioso
# Phillip Island                                Australia                           Andrea Dovizioso
# Chang International Circuit                   Tailandia                           Johann Zarco
# Mobility Resort Motegi                        Japao                               Franco Morbidelli
# MotorLand Aragon                              Espanha                             Brad Binder
# Misano World Circuit Marco Simoncelli         San Marino                          Remy Gardner
# Red Bull Ring - Spielberg                     Austria                             Alex Marquez
# Silverstone Circuit                           Reino Unido                         Miguel Oliveira
# TT Circuit Assen                              Holanda                             Andrea Dovizioso
# Sachsenring                                   Alemanha                            Danilo Petrucci
# Circuit de Barcelona-Catalunya                Espanha                             Lorenzo Savadori
# Autodromo Internazionale del Mugello          Italia                              Maverick ViÃ±ales
# Le Mans                                       Franca                              Takaaki Nakagami
# Circuito de Jerez - Angel Nieto               Espanha                             Marco Bezzecchi
# Autodromo Internacional do Algarve            Portugal                            Danilo Petrucci
# Circuit Of The Americas                       Estados Unidos da America           Andrea Dovizioso
# Termas de Rio Hondo                           Argentina                           Aleix Espargaro
# Pertamina Mandalika Circuit                   Indonesia                           Pol Espargaro
# Lusail International Circuit                  Qatar                               Fabio Di Giannantonio
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  2
#    Classificação Geral !!!
#
# Ordem      Nome           Pontos
#
#  1    Andrea Dovizioso          200
#  2    Takaaki Nakagami          175
#  3    Marc Marquez              147
#  4    Alex Marquez              139
#  5    Raul Fernandez            130
#  6    Johann Zarco              124
#  7    Francesco Bagnaia         121
#  8    Aleix Espargaro           114
#  9    Jack Miller               110
# 10    Lorenzo Savadori          110
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  2
#    Classificação Geral !!!
#
# Ordem      Nome           Pontos
#
#  1    Andrea Dovizioso          200
#  2    Takaaki Nakagami          175
#  3    Marc Marquez              147
#  4    Alex Marquez              139
#  5    Raul Fernandez            130
#  6    Johann Zarco              124
#  7    Francesco Bagnaia         121
#  8    Aleix Espargaro           114
#  9    Jack Miller               110
# 10    Lorenzo Savadori          110
#
#  1 Menu anterior
#
#
#  2 Exit
