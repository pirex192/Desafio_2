# %%
import random
import re
import sys
from os import system

fonte_pilotos = open("Pilotos_2022.txt",'r')
fonte_circuitos = open("Circuito_2022.txt",'r')
fonte_pontos = open("Pontos_2022.txt",'r')

pilotos = {}
circuitos = {}
pontos = {}
lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
flag = 0

for x in fonte_pilotos:
#    piloto = x.strip().split(',')
    numero, nome, pais, equipa, mota = x.strip().split(',')
    pilotos[nome] = [numero, pais, equipa, mota, []]
fonte_pilotos.close()

for c in fonte_circuitos:
    nome, pais, distancia = c.strip().split(',')
    circuitos[nome] = [pais, distancia, []]
fonte_circuitos.close()

for p in fonte_pontos:
    ponto = p.strip().split(',')
    pontos[ponto[0]] = ponto[1]
fonte_pontos.close()

def Pilotos():
    lista_menu = ['Listar pilotos', 'Classificacao geral', 'Classificacao por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)    
    input("Press Enter to Continue\n")
    system('cls')

def ListarPilotos():
    print('\n', 'Nome'.ljust(22),'Numero'.ljust(7), 'Pais'.ljust(6), 'Equipa'.ljust(30), 'Mota','\n')    
    for x in pilotos:
        print(x.ljust(25), pilotos[x][0].ljust(5), pilotos[x][1].ljust(5), pilotos[x][2].ljust(30), pilotos[x][3])
    print('\n', '\n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def ClassificacaoGeral():
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
   
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificacao Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        else:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def MenuClassificacaoPorGP():
    lista_menu = ['Escolher circuito', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def EscolherCircuitoPilotos():
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 1)
    input("Press Enter to Continue\n")
    system('cls')

def ClassificacaoPorGP(circuito):
   
    print('\n' + circuito + '!!!\n\nOrdem      Nome           Pontos\n')
    i=1
    if circuitos[circuito][2] != []:
        for x in circuitos[circuito][2]:        
            if i < 10:
                print('', i, '  ', x[2].ljust(25), x[1])
            else:
                print(i, '  ',  x[2].ljust(25), x[1])            
            i+=1
    else:
        print('Tem que escolher um GP realizado !!!')
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def GrandePremio():
    lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def RealizarGP():
   
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 2)
    input("Press Enter to Continue\n")
    system('cls')

def Realizar_GP(circuito):
   
    replica_pilotos = list(pilotos)
    i=1
    while replica_pilotos:
        try:
            pont = int(pontos[str(i)])
        except:
            pont = 0
        piloto = random.choice(replica_pilotos)
        replica_pilotos.remove(piloto)
        pilotos[piloto][4].append((circuito, pont))
        circuitos[circuito][2].append((pilotos[piloto][2],pont, piloto))

        i+=1
 
    print('\n GP realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def VencedoresPorGP():
    print("circuitos".ljust(20), "pais".ljust(20), "pilotos")
    for x in circuitos:
        print(x.ljust(40), circuitos[x][0].ljust(20), circuitos[x][2][0][2])
    
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def Campeonato():
    lista_menu = ['Realizar campeonato', 'Os dez primeiros do campeonato', 'Os primeiros de cada GP','As tres melhores equipas', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def RealizarCampeonato():
    for gp in circuitos:
        replica_pilotos = list(pilotos)
        i=1
        while replica_pilotos:
            try:
                pont = int(pontos[str(i)])
            except:
                pont = 0
            piloto = random.choice(replica_pilotos)
            replica_pilotos.remove(piloto)
            pilotos[piloto][4].append((gp, pont))
            circuitos[gp][2].append((pilotos[piloto][2],pont, piloto))

            i+=1
 
    print('\n Campeonato realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def DezPrimeiros():
   
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Cl !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        elif i<11:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls') 

def TresEquipas():
   
    equipas = {}
    pilotos = {}

    for x in circuitos:
        circuito = circuitos[x]
        classificacao = circuito[2]
        for c in classificacao:
            equipa, pontos, piloto = c
            if equipa in equipas:
                equipas[equipa] = equipas[equipa] + pontos
            else:
                equipas[equipa] = pontos
            if piloto in pilotos:
                pilotos[piloto] = pilotos[piloto] + pontos
            else:
                pilotos[piloto] = pontos            
    # print(sorted(equipas.items(), reverse=True, key=lambda item: item[1]))
    # print(sorted(pilotos.items(), reverse=True, key=lambda item: item[1]))
    tres = sorted(equipas.items(), reverse=True, key=lambda item: item[1])
    primeiros(tres, 3)
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def primeiros(equipas, limite):
    i = 0
    for e in equipas:
        if i < limite:
            print('{} {}'.format(e[0], e[1]))
        i = i+1

def Exit():  
    system('cls')
    print("Ate a proxima!")
    sys.exit()
    
def MenuAnterior():
    lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def display_menu(menu_items):
    for x in menu_items:
        print('\n', x, menu_items.get(x), '\n')

def Menu(lista_menu, flag):
    menu_items = dict(enumerate(lista_menu, start=1))
    while True:
        display_menu(menu_items)        
        try:
            selection = int(input("Escolha um valor do menu: \n"))
        except:
            print('Introduza um algarismo !')
        else:
            try:
                selected = menu_items[selection]
                break
            except:
                print('Escolha um valor do menu !')
            else:
                break
    nome_menu = {'Pilotos' : Pilotos,
                 'Grande Premio' : GrandePremio,
                 'Campeonato' : Campeonato,
                 'Exit' : Exit,
                 'Os dez primeiros do campeonato' : DezPrimeiros,
                 'As tres melhores equipas' : TresEquipas,
                 'Menu anterior' : MenuAnterior,
                 'Os primeiros de cada GP' : VencedoresPorGP,
                 'Realizar GP' : RealizarGP,
                 'Classificacao geral' : ClassificacaoGeral,
                 'Realizar campeonato' : RealizarCampeonato,
                 'Escolher circuito' : EscolherCircuitoPilotos,
                 'Listar pilotos' : ListarPilotos,
                 'Classificacao por GP' : MenuClassificacaoPorGP,
                 'Os vencedores por GP' : VencedoresPorGP
    }
    if flag == 0:
        executa_funcao = nome_menu[selected]
        executa_funcao()
    elif flag == 1:
        ClassificacaoPorGP(selected)
    elif flag == 2:
        Realizar_GP(selected)
        
Menu(lista_menu,0)
# Out:
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
#  GP realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
#  GP realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
#  1 Listar pilotos
#
#
#  2 Classificacao geral
#
#
#  3 Classificacao por GP
#
#
#  4 Menu anterior
#
#
#  5 Exit
# Escolha um valor do menu:
#  3
#  1 Escolher circuito
#
#
#  2 Menu anterior
#
#
#  3 Exit
# Escolha um valor do menu:
#  1
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
# Circuit Ricardo Tormo!!!
#
# Ordem      Nome           Pontos
#
#  1    Raul Fernandez            25
#  2    Enea Bastianini           20
#  3    Francesco Bagnaia         16
#  4    Remy Gardner              13
#  5    Takaaki Nakagami          11
#  6    Kazuki Watanabe           10
#  7    Alex Rins                 9
#  8    Pol Espargaro             8
#  9    Jack Miller               7
# 10    Marco Bezzecchi           6
# 11    Franco Morbidelli         5
# 12    Stefan Bradl              4
# 13    Jorge Martin              3
# 14    Joan Mir                  2
# 15    Johann Zarco              1
# 16    Alex Marquez              0
# 17    Michele Pirro             0
# 18    Fabio Di Giannantonio     0
# 19    Brad Binder               0
# 20    Aleix Espargaro           0
# 21    Marc Marquez              0
# 22    Tetsuta Nagashima         0
# 23    Darryn Binder             0
# 24    Lorenzo Savadori          0
# 25    Luca Marini               0
# 26    Cal Crutchlow             0
# 27    Fabio Quartararo          0
# 28    Andrea Dovizioso          0
# 29    Miguel Oliveira           0
# 30    Danilo Petrucci           0
# 31    Maverick Vi̱ales         0
# 32    Marc Marquez              25
# 33    Takaaki Nakagami          20
# 34    Marco Bezzecchi           16
# 35    Miguel Oliveira           13
# 36    Cal Crutchlow             11
# 37    Johann Zarco              10
# 38    Lorenzo Savadori          9
# 39    Jack Miller               8
# 40    Joan Mir                  7
# 41    Luca Marini               6
# 42    Fabio Quartararo          5
# 43    Francesco Bagnaia         4
# 44    Alex Rins                 3
# 45    Aleix Espargaro           2
# 46    Stefan Bradl              1
# 47    Darryn Binder             0
# 48    Remy Gardner              0
# 49    Raul Fernandez            0
# 50    Alex Marquez              0
# 51    Tetsuta Nagashima         0
# 52    Franco Morbidelli         0
# 53    Brad Binder               0
# 54    Fabio Di Giannantonio     0
# 55    Michele Pirro             0
# 56    Danilo Petrucci           0
# 57    Jorge Martin              0
# 58    Andrea Dovizioso          0
# 59    Enea Bastianini           0
# 60    Kazuki Watanabe           0
# 61    Maverick Vi̱ales         0
# 62    Pol Espargaro             0
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
# circuitos            pais                 pilotos
# Circuit Ricardo Tormo                    Espanha              Raul Fernandez
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in <module>
#     291         Realizar_GP(selected)
#     292
# --> 293 Menu(lista_menu,0)
#     294
#     295
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in GrandePremio()
#     103 def GrandePremio():
#     104     lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']
# --> 105     Menu(lista_menu, 0)
#     106     input("Press Enter to Continue\n")
#     107     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in RealizarGP()
#     112     for x in circuitos:
#     113         lista_menu.append(x)
# --> 114     Menu(lista_menu, 2)
#     115     input("Press Enter to Continue\n")
#     116     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     289         ClassificacaoPorGP(selected)
#     290     elif flag == 2:
# --> 291         Realizar_GP(selected)
#     292
#     293 Menu(lista_menu,0)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Realizar_GP(circuito)
#     135
#     136     lista_menu = ['Menu anterior', 'Exit']
# --> 137     Menu(lista_menu, 0)
#     138     input("Press Enter to Continue\n")
#     139     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in MenuAnterior()
#     243 def MenuAnterior():
#     244     lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
# --> 245     Menu(lista_menu, 0)
#     246     input("Press Enter to Continue\n")
#     247     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in GrandePremio()
#     103 def GrandePremio():
#     104     lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']
# --> 105     Menu(lista_menu, 0)
#     106     input("Press Enter to Continue\n")
#     107     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in RealizarGP()
#     112     for x in circuitos:
#     113         lista_menu.append(x)
# --> 114     Menu(lista_menu, 2)
#     115     input("Press Enter to Continue\n")
#     116     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     289         ClassificacaoPorGP(selected)
#     290     elif flag == 2:
# --> 291         Realizar_GP(selected)
#     292
#     293 Menu(lista_menu,0)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Realizar_GP(circuito)
#     135
#     136     lista_menu = ['Menu anterior', 'Exit']
# --> 137     Menu(lista_menu, 0)
#     138     input("Press Enter to Continue\n")
#     139     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in MenuAnterior()
#     243 def MenuAnterior():
#     244     lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
# --> 245     Menu(lista_menu, 0)
#     246     input("Press Enter to Continue\n")
#     247     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Pilotos()
#      32 def Pilotos():
#      33     lista_menu = ['Listar pilotos', 'Classificacao geral', 'Classificacao por GP', 'Menu anterior', 'Exit']
# ---> 34     Menu(lista_menu, 0)
#      35     input("Press Enter to Continue\n")
#      36     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in MenuClassificacaoPorGP()
#      71 def MenuClassificacaoPorGP():
#      72     lista_menu = ['Escolher circuito', 'Menu anterior', 'Exit']
# ---> 73     Menu(lista_menu, 0)
#      74     input("Press Enter to Continue\n")
#      75     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in EscolherCircuitoPilotos()
#      79     for x in circuitos:
#      80         lista_menu.append(x)
# ---> 81     Menu(lista_menu, 1)
#      82     input("Press Enter to Continue\n")
#      83     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     287         executa_funcao()
#     288     elif flag == 1:
# --> 289         ClassificacaoPorGP(selected)
#     290     elif flag == 2:
#     291         Realizar_GP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in ClassificacaoPorGP(circuito)
#      97         print('Tem que escolher um GP realizado !!!')
#      98     lista_menu = ['Menu anterior', 'Exit\n']
# ---> 99     Menu(lista_menu, 0)
#     100     input("Press Enter to Continue\n")
#     101     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in MenuAnterior()
#     243 def MenuAnterior():
#     244     lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
# --> 245     Menu(lista_menu, 0)
#     246     input("Press Enter to Continue\n")
#     247     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in GrandePremio()
#     103 def GrandePremio():
#     104     lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']
# --> 105     Menu(lista_menu, 0)
#     106     input("Press Enter to Continue\n")
#     107     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in Menu(lista_menu, flag)
#     285     if flag == 0:
#     286         executa_funcao = nome_menu[selected]
# --> 287         executa_funcao()
#     288     elif flag == 1:
#     289         ClassificacaoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_15408\2070151892.py in VencedoresPorGP()
#     142     print("circuitos".ljust(20), "pais".ljust(20), "pilotos")
#     143     for x in circuitos:
# --> 144         print(x.ljust(40), circuitos[x][0].ljust(20), circuitos[x][2][0][2])
#     145
#     146     lista_menu = ['Menu anterior', 'Exit']
#
# IndexError: list index out of range
