# %%
import random
import re
import sys
from os import system

fonte_pilotos = open("../../jupyter/Desafio_2/Pilotos_2022.txt",'r')
fonte_circuitos = open("../../jupyter/Desafio_2/Circuito_2022.txt",'r')
fonte_pontos = open("../../jupyter/Desafio_2/Pontos_2022.txt",'r')

pilotos = {}
circuitos = {}
pontos = {}
lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
resultados_gp = {}
flag = 0

for x in fonte_pilotos:
#    piloto = x.strip().split(',')
    numero, nome, pais, equipa, mota = x.strip().split(',')
    pilotos[nome] = [numero, pais, equipa, mota, []]
fonte_pilotos.close()

for c in fonte_circuitos:
    nome, país, distancia = c.strip().split(',')
    circuitos[nome] = [país, distancia]
fonte_circuitos.close()

for p in fonte_pontos:
    ponto = p.strip().split(',')
    pontos[ponto[0]] = ponto[1]
fonte_pontos.close()

def display_menu(menu_items):
    for x in menu_items:
        print('\n', x, menu_items.get(x), '\n')

def Pilotos():
    lista_menu = ['Listar pilotos', 'Classificação geral', 'Classificação por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)    
    input("Press Enter to Continue\n")
    system('cls')


def GrandePremio():
    lista_menu = ['Realizar GP', 'Escolher  circuito', 'Os vencedores por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')


def Campeonato():
    lista_menu = ['Realizar campeonato', 'Os dez primeiros do campeonato', 'Os primeiros de cada GP','As três melhores equipas', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')


def Exit():  
    system('cls')
    print("Goodbye")
    sys.exit()
    
def MenuClassificaçãoPorGP():
    lista_menu = ['Escolher circuito', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def ListarPilotos():
    print('\n', 'Nome'.ljust(22),'Número'.ljust(7), 'País'.ljust(6), 'Equipa'.ljust(30), 'Mota','\n')    
    for x in pilotos:
        print(x.ljust(25), pilotos[x][0].ljust(5), pilotos[x][1].ljust(5), pilotos[x][2].ljust(30), pilotos[x][3])
    print('\n', '\n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def ClassificaçãoPorGP(circuito):
    
    print('\n' + circuito + '!!!\n\nOrdem      Nome           Pontos\n')
    i=1
    try:
        for x in resultados_gp[circuito]:
            if i < 10:
                print('', i, '  ', x[0].ljust(25), x[1])
            else:
                print(i, '  ',  x[0].ljust(25), x[1])            
            i+=1
    except:
        print('Tem que escolher um GP realizado !!!')
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def VencedoresPorGP():

#    print('\n' + circuito + '!!!\n\nOrdem      Nome           Pontos\n')
    i=1
    for x in resultados_gp:
        if i < 10:
            print('', i, '  ', x.ljust(40), resultados_gp[x][0][0].ljust(25), resultados_gp[x][0][1]) #, x, x.values()[0].ljust(25), x.values()[1])
        else:
            print(i, '  ', x.ljust(40), resultados_gp[x][0][0].ljust(25), resultados_gp[x][0][1]) #, x, x.values()[0].ljust(25), x.values()[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def EscolherCircuitoPilotos():
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 1)
    input("Press Enter to Continue\n")
    system('cls')
    
def EscolherCircuitoGP():
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 2)
    input("Press Enter to Continue\n")
    system('cls')
    
def RealizarCampeonato():
    for gp in circuitos:
        replica_pilotos = list(pilotos)
        classificacao = []
        i=1
        while replica_pilotos:
            try:
                temp = int(pontos[str(i)])
            except:
                temp = 0
            piloto = random.choice(replica_pilotos)
            replica_pilotos.remove(piloto)
            piloto_temp = [piloto, temp]
            pilotos[piloto][4].append((gp, temp))
            classificacao.append(piloto_temp)
            i+=1
        resultados_gp[gp] = classificacao
            
    print('\n Campeonato realizado !!! \n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def PoolePosition():
    print('Poole position')
    input("Press Enter to Continue\n")
    system('cls')
    
def ClassificaçãoGeral():
#    print('Classificação geral')
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificação Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        else:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def RealizarGP():
    print('\nEscolha o circuito : \n')
    
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 2)
    
    input("Press Enter to Continue\n")
    system('cls')
    
def Realizar_GP(circuito):
    
    print('\n', circuito, '\n')

    replica_pilotos = list(pilotos)
    classificacao = []
    i=1
    while replica_pilotos:
        try:
            pont = int(pontos[str(i)])
        except:
            pont = 0
        piloto = random.choice(replica_pilotos)
        replica_pilotos.remove(piloto)
        piloto_pont = [piloto, pont]
        pilotos[piloto][4].append((circuito, pont))
        classificacao.append(piloto_pont)
        i+=1
    resultados_gp[circuito] = classificacao
            
    print('\n GP realizado !!! \n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

    
def PrimeirosCadaGP():
    print('Os primeiros de cada GP')
    input("Press Enter to Continue\n")
    system('cls')

def DezPrimeiros():
    print("DezPrimeiros")
    input("Press Enter to Continue\n")
    system('cls')
    
def TresEquipas():
    print("TresEquipas")
    input("Press Enter to Continue\n")
    system('cls')

def MenuAnterior():
    lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def Menu(lista_menu, flag):

    menu_items = dict(enumerate(lista_menu, start=1))
    display_menu(menu_items)
    selection = int(input("Escolha um valor do menu: \n"))
    selected = menu_items[selection]
    nome_menu = {'Pilotos' : Pilotos,
                 'Grande Premio' : GrandePremio,
                 'Campeonato' : Campeonato,
                 'Exit' : Exit,
                 'Os dez primeiros' : DezPrimeiros,
                 'As três melhores equipas' : TresEquipas,
                 'Menu anterior' : MenuAnterior,
                 'Os primeiros de cada GP' : PrimeirosCadaGP,
                 'Realizar GP' : RealizarGP,
                 'Classificação geral' : ClassificaçãoGeral,
                 'Poole position' : PoolePosition,
                 'Realizar campeonato' : RealizarCampeonato,
                 'Escolher circuito' : EscolherCircuitoPilotos,
                 'Escolher  circuito' : EscolherCircuitoGP,
                 'Listar pilotos' : ListarPilotos,
                 'Classificação por GP' : MenuClassificaçãoPorGP,
                 'Os vencedores por GP' : VencedoresPorGP
    }
    if flag == 0:
        executa_funcao = nome_menu[selected]
        executa_funcao()
    elif flag == 1:
        ClassificaçãoPorGP(selected)
    elif flag == 2:
        Realizar_GP(selected)
    
Menu(lista_menu,0)
# Out:
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  3
#  1 Realizar campeonato
#
#
#  2 Os dez primeiros do campeonato
#
#
#  3 Os primeiros de cada GP
#
#
#  4 As três melhores equipas
#
#
#  5 Menu anterior
#
#
#  6 Exit
# Escolha um valor do menu:
#  1
#  Campeonato realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Escolher  circuito
#
#
#  3 Os vencedores por GP
#
#
#  4 Menu anterior
#
#
#  5 Exit
# Escolha um valor do menu:
#  3
#  1    Circuit Ricardo Tormo                    Marco Bezzecchi           25
#  2    Sepang International Circuit             Jorge Martin              25
#  3    Phillip Island                           Marc Marquez              25
#  4    Chang International Circuit              Fabio Quartararo          25
#  5    Mobility Resort Motegi                   Francesco Bagnaia         25
#  6    MotorLand Aragon                         Michele Pirro             25
#  7    Misano World Circuit Marco Simoncelli    Marco Bezzecchi           25
#  8    Red Bull Ring - Spielberg                Francesco Bagnaia         25
#  9    Silverstone Circuit                      Fabio Quartararo          25
# 10    TT Circuit Assen                         Lorenzo Savadori          25
# 11    Sachsenring                              Aleix Espargaro           25
# 12    Circuit de Barcelona-Catalunya           Fabio Quartararo          25
# 13    Autodromo Internazionale del Mugello     Aleix Espargaro           25
# 14    Le Mans                                  Alex Rins                 25
# 15    Circuito de Jerez - Angel Nieto          Fabio Quartararo          25
# 16    Autodromo Internacional do Algarve       Stefan Bradl              25
# 17    Circuit Of The Americas                  Lorenzo Savadori          25
# 18    Termas de Rio Hondo                      Andrea Dovizioso          25
# 19    Pertamina Mandalika Circuit              Alex Rins                 25
# 20    Lusail International Circuit             Fabio Di Giannantonio     25
#
#  1 Menu anterior
#
#
#  2 Exit
