# %%
import random
import re
import sys
from os import system

fonte_pilotos = open("../../jupyter/Desafio_2/Pilotos_2022.txt",'r')
fonte_circuitos = open("../../jupyter/Desafio_2/Circuito_2022.txt",'r')
fonte_pontos = open("../../jupyter/Desafio_2/Pontos_2022.txt",'r')

pilotos = {}
circuitos = {}
pontos = {}
lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
flag = 0

for x in fonte_pilotos:
#    piloto = x.strip().split(',')
    numero, nome, pais, equipa, mota = x.strip().split(',')
    pilotos[nome] = [numero, pais, equipa, mota, []]
fonte_pilotos.close()

for c in fonte_circuitos:
    nome, país, distancia = c.strip().split(',')
    circuitos[nome] = [país, distancia, []]
fonte_circuitos.close()

for p in fonte_pontos:
    ponto = p.strip().split(',')
    pontos[ponto[0]] = ponto[1]
fonte_pontos.close()

def Pilotos():
    lista_menu = ['Listar pilotos', 'Classificação geral', 'Classificação por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)    
    input("Press Enter to Continue\n")
    system('cls')

def ListarPilotos():
    print('\n', 'Nome'.ljust(22),'Número'.ljust(7), 'País'.ljust(6), 'Equipa'.ljust(30), 'Mota','\n')    
    for x in pilotos:
        print(x.ljust(25), pilotos[x][0].ljust(5), pilotos[x][1].ljust(5), pilotos[x][2].ljust(30), pilotos[x][3])
    print('\n', '\n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def ClassificaçãoGeral():
    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    print('\n   Classificação Geral !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in venc_ordenada:
        if i < 10:
            print('', i, '  ', x[0].ljust(25), x[1])
        else:
            print(i, '  ',  x[0].ljust(25), x[1])            
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls') 

def MenuClassificaçãoPorGP():
    lista_menu = ['Escolher circuito', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def EscolherCircuitoPilotos():
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 1)
    input("Press Enter to Continue\n")
    system('cls')

def ClassificaçãoPorGP(circuito):
    
    print('\n' + circuito + '!!!\n\nOrdem      Nome           Pontos\n')
    i=1
    if circuitos[circuito][2] != []:
        for x in circuitos[circuito][2]:        
            if i < 10:
                print('', i, '  ', x[2].ljust(25), x[1])
            else:
                print(i, '  ',  x[2].ljust(25), x[1])            
            i+=1
    else:
        print('Tem que escolher um GP realizado !!!')
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def GrandePremio():
    lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def RealizarGP():
    print('\nEscolha o circuito : \n')
    
    lista_menu = []
    for x in circuitos:
        lista_menu.append(x)    
    Menu(lista_menu, 2)
    
    input("Press Enter to Continue\n")
    system('cls')
    
def Realizar_GP(circuito):
    
    print('\n', circuito, '\n')

    if circuitos[circuito][2] != [] :
        print('\n Já realizou o circuito :', circuito)
    else:
        replica_pilotos = list(pilotos)
        i=1
        while replica_pilotos:
            try:
                pont = int(pontos[str(i)])
            except:
                pont = 0
            piloto = random.choice(replica_pilotos)
            replica_pilotos.remove(piloto)
            pilotos[piloto][4].append((circuito, pont))
            circuitos[circuito][2].append((pilotos[piloto][2],pont, piloto))
            i+=1           
        print('\n GP realizado !!! \n')
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def VencedoresPorGP():
    i=1
    for x in circuitos:
        if circuitos[x][2] == []:
            print('Tem que realizar o campeonato !!!')        
    else:
        print('\nVencedores por GP !!!\n')
    try:
        for x in circuitos:
                if i < 10:
                    print('', i, '  ', x.ljust(40), circuitos[x][0].ljust(25), circuitos[x][2][0][2])
                else:
                    print(i, '  ', x.ljust(40), circuitos[x][0].ljust(25), circuitos[x][2][0][2])            
                i+=1
    except:
        print('Tem que realizar o campeonato !!!')        
    lista_menu = ['Menu anterior', 'Exit\n']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def Campeonato():
    lista_menu = ['Realizar campeonato', 'Os dez primeiros do campeonato', 'Os primeiros de cada GP','As três melhores equipas', 'Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def RealizarCampeonato():

    for gp in circuitos:
        replica_pilotos = list(pilotos)
        i=1
        while replica_pilotos:
            try:
                pont = int(pontos[str(i)])
            except:
                pont = 0
            piloto = random.choice(replica_pilotos)
            replica_pilotos.remove(piloto)
            pilotos[piloto][4].append((gp, pont))
            circuitos[gp][2].append((pilotos[piloto][2],pont, piloto))

            i+=1
  
    print('\n Campeonato realizado !!! \n')

    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def DezPrimeiros():

    venc_ordenada = []    
    res_final_gp = []
    for x in pilotos:
        soma = sum(pontuacao[1] for pontuacao in pilotos[x][4])
        res_final_gp.append([x, soma])
    
    def TakeSecond(elem):
        return elem[1]
    venc_ordenada = sorted(res_final_gp, key=TakeSecond, reverse=True)
    
    print('\n   Os dez primeiros !!! \n\nOrdem      Nome           Pontos\n')

    i=1
    for x in venc_ordenada:
        if i < 10:
            print(' ', i, '  ', x[0].ljust(25), x[1])
        elif i < 11:
            print('', i, '  ', x[0].ljust(25), x[1])            
        else:
            break          
        i+=1
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')

def TresEquipas():
    res_final_equipas = {} 
    for x in circuitos:        
        tmp = 0  
        for y in circuitos[x][2]:
            for z in circuitos[x][2]:
                if y[0] == z[0]:
                    tmp = tmp + z[1]
                    
            res_final_equipas[y[0]] = tmp
            
    res_final = dict(sorted(res_final_equipas.items(), key=lambda item: item[1], reverse = True))
    
#    print(res_final)
    print('\n   As três primeiras equipas !!! \n\nOrdem      Nome           Pontos\n')
    i=1
    for x in res_final:
        if i < 4:
            print(' ', i, '  ', x.ljust(40), res_final_equipas[x])
#        else:
#            print('', i, '  ', x.ljust(40), res_final_equipas[x])             
        i+=1
    
    lista_menu = ['Menu anterior', 'Exit']    
    Menu(lista_menu, 0)

    input("Press Enter to Continue\n")
    system('cls')

def Exit():  
    system('cls')
    print("Goodbye")
    sys.exit()
    
def MenuAnterior():
    lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
    Menu(lista_menu, 0)
    input("Press Enter to Continue\n")
    system('cls')
    
def display_menu(menu_items):
    for x in menu_items:
        print('\n', x, menu_items.get(x), '\n')

def Menu(lista_menu, flag):
    menu_items = dict(enumerate(lista_menu, start=1))
    while True:
        display_menu(menu_items)        
        try:
            selection = int(input("Escolha um valor do menu: \n"))
        except:
            print('Introduza um algarismo !')
        else:
            try:
                selected = menu_items[selection]
                break
            except:
                print('Escolha um valor do menu !')
            else:
                break
    nome_menu = {'Pilotos' : Pilotos,
                 'Grande Premio' : GrandePremio,
                 'Campeonato' : Campeonato,
                 'Exit' : Exit,
                 'Os dez primeiros do campeonato' : DezPrimeiros,
                 'As três melhores equipas' : TresEquipas,
                 'Menu anterior' : MenuAnterior,
                 'Os primeiros de cada GP' : VencedoresPorGP,
                 'Realizar GP' : RealizarGP,
                 'Classificação geral' : ClassificaçãoGeral,
                 'Realizar campeonato' : RealizarCampeonato,
                 'Escolher circuito' : EscolherCircuitoPilotos,
                 'Listar pilotos' : ListarPilotos,
                 'Classificação por GP' : MenuClassificaçãoPorGP,
                 'Os vencedores por GP' : VencedoresPorGP
    }
    if flag == 0:
        executa_funcao = nome_menu[selected]
        executa_funcao()
    elif flag == 1:
        ClassificaçãoPorGP(selected)
    elif flag == 2:
        Realizar_GP(selected)
    
Menu(lista_menu,0)
# Out:
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  1
# Escolha o circuito :
#
#
#  1 Circuit Ricardo Tormo
#
#
#  2 Sepang International Circuit
#
#
#  3 Phillip Island
#
#
#  4 Chang International Circuit
#
#
#  5 Mobility Resort Motegi
#
#
#  6 MotorLand Aragon
#
#
#  7 Misano World Circuit Marco Simoncelli
#
#
#  8 Red Bull Ring - Spielberg
#
#
#  9 Silverstone Circuit
#
#
#  10 TT Circuit Assen
#
#
#  11 Sachsenring
#
#
#  12 Circuit de Barcelona-Catalunya
#
#
#  13 Autodromo Internazionale del Mugello
#
#
#  14 Le Mans
#
#
#  15 Circuito de Jerez - Angel Nieto
#
#
#  16 Autodromo Internacional do Algarve
#
#
#  17 Circuit Of The Americas
#
#
#  18 Termas de Rio Hondo
#
#
#  19 Pertamina Mandalika Circuit
#
#
#  20 Lusail International Circuit
# Escolha um valor do menu:
#  1
#  Circuit Ricardo Tormo
#
#
#  GP realizado !!!
#
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  1
#  1 Pilotos
#
#
#  2 Grande Premio
#
#
#  3 Campeonato
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
#  1 Realizar GP
#
#
#  2 Os vencedores por GP
#
#
#  3 Menu anterior
#
#
#  4 Exit
# Escolha um valor do menu:
#  2
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
# Tem que realizar o campeonato !!!
#
# Vencedores por GP !!!
#
#  1    Circuit Ricardo Tormo                    Espanha                   Cal Crutchlow
# Tem que realizar o campeonato !!!
#
#  1 Menu anterior
#
#
#  2 Exit
# Escolha um valor do menu:
#  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in <module>
#     306         Realizar_GP(selected)
#     307
# --> 308 Menu(lista_menu,0)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     300     if flag == 0:
#     301         executa_funcao = nome_menu[selected]
# --> 302         executa_funcao()
#     303     elif flag == 1:
#     304         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in GrandePremio()
#     103 def GrandePremio():
#     104     lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']
# --> 105     Menu(lista_menu, 0)
#     106     input("Press Enter to Continue\n")
#     107     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     300     if flag == 0:
#     301         executa_funcao = nome_menu[selected]
# --> 302         executa_funcao()
#     303     elif flag == 1:
#     304         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in RealizarGP()
#     113     for x in circuitos:
#     114         lista_menu.append(x)
# --> 115     Menu(lista_menu, 2)
#     116
#     117     input("Press Enter to Continue\n")
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     304         ClassificaçãoPorGP(selected)
#     305     elif flag == 2:
# --> 306         Realizar_GP(selected)
#     307
#     308 Menu(lista_menu,0)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Realizar_GP(circuito)
#     139         print('\n GP realizado !!! \n')
#     140     lista_menu = ['Menu anterior', 'Exit']
# --> 141     Menu(lista_menu, 0)
#     142     input("Press Enter to Continue\n")
#     143     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     300     if flag == 0:
#     301         executa_funcao = nome_menu[selected]
# --> 302         executa_funcao()
#     303     elif flag == 1:
#     304         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in MenuAnterior()
#     258 def MenuAnterior():
#     259     lista_menu = ['Pilotos', 'Grande Premio', 'Campeonato', 'Exit']
# --> 260     Menu(lista_menu, 0)
#     261     input("Press Enter to Continue\n")
#     262     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     300     if flag == 0:
#     301         executa_funcao = nome_menu[selected]
# --> 302         executa_funcao()
#     303     elif flag == 1:
#     304         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in GrandePremio()
#     103 def GrandePremio():
#     104     lista_menu = ['Realizar GP', 'Os vencedores por GP', 'Menu anterior', 'Exit']
# --> 105     Menu(lista_menu, 0)
#     106     input("Press Enter to Continue\n")
#     107     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     300     if flag == 0:
#     301         executa_funcao = nome_menu[selected]
# --> 302         executa_funcao()
#     303     elif flag == 1:
#     304         ClassificaçãoPorGP(selected)
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in VencedoresPorGP()
#     160         print('Tem que realizar o campeonato !!!')
#     161     lista_menu = ['Menu anterior', 'Exit\n']
# --> 162     Menu(lista_menu, 0)
#     163     input("Press Enter to Continue\n")
#     164     system('cls')
#
# ~\AppData\Local\Temp\ipykernel_9632\524547935.py in Menu(lista_menu, flag)
#     299     }
#     300     if flag == 0:
# --> 301         executa_funcao = nome_menu[selected]
#     302         executa_funcao()
#     303     elif flag == 1:
#
# KeyError: 'Exit\n'
